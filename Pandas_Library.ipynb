# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshisangani64-beep/numpy_all_code/blob/main/Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Introduction to Pandas

# %% [markdown]
# Task 1.1: Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# Task 1.2: Understanding Pandas Data Structures

# %%
#  two primary data structures in Pandas means
# pandas is python power full library
# pandas in two primary data structer use
# pandas in Series and Dataframe use
# Series is singel column data and multipel rows
# dataframe is two or more column and row
# pandas in  row and column structer in data are show mostly

# %% [markdown]
# 2. Series

# %% [markdown]
# Task 2.1: Creating a Series from a List

# %%
fruits = ['apple', 'banana', 'cherry', 'date']
s = pd.Series(data=fruits,name="fruits")
s
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3      date
# Name: fruits, dtype: object

# %% [markdown]
# Task 2.2: Creating a Series with Custom Indices

# %%
color  = {"color1":"red","color2":"green","color3":"blue"}
c = pd.Series(data=color,index=["color1","color2","color3"],name="colors")
c
# Out:
# color1      red
# color2    green
# color3     blue
# Name: colors, dtype: object

# %% [markdown]
# Task 2.3: Accessing Elements in a Series

# %%
# Using the fruits Series, access and print the element at index 1
s[1]
# Out:
# 'banana'

# %%
# Using the colors Series, access and print the element with the index 'color2'.
c["color2"]
# Out:
# 'green'

# %% [markdown]
# 3. DataFrame

# %% [markdown]
# Task 3.1: Creating a DataFrame from a Dictionary of Lists

# %%
student_data = {
'name': ['Alice', 'Bob', 'Charlie'],
'age': [20, 21, 19],
'major': ['CS', 'Engineering', 'Math']
}
dfs = pd.DataFrame(student_data)
dfs
# Out:
#       name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math

# %% [markdown]
# Task 3.2: Creating a DataFrame from a List of Dictionaries

# %%
employee_data = {"name":["David","Eve","Frank"],
                 "salary":[50000,60000,55000],
                 "department":["Sales","Marketing","Sales"]}
dfe = pd.DataFrame(employee_data)
dfe
# Out:
#     name  salary department
# 0  David   50000      Sales
# 1    Eve   60000  Marketing
# 2  Frank   55000      Sales

# %% [markdown]
# Task 3.3: Creating a DataFrame from a NumPy Array

# %%
import numpy as np

# %%
data_array = np.array([[5,6],[7,5],[8,4]])
data_array.shape
# Out:
# (3, 2)

# %%
data_array
# Out:
# array([[5, 6],
#        [7, 5],
#        [8, 4]])

# %%
random_df = {"Cloumn1":data_array[0:3,0],
             "Cloumn2":data_array[0:3,1]
             }
df = pd.DataFrame(random_df)
df
# Out:
#    Cloumn1  Cloumn2
# 0        5        6
# 1        7        5
# 2        8        4

# %% [markdown]
# 4. Exploring Data (Series and DataFrame)

# %% [markdown]
# Task 4.1: Exploring a Series

# %%
# The number of elements in the Series
s.shape
# Out:
# (4,)

# %%
#The unique values in the Series
s.unique()
# Out:
# array(['apple', 'banana', 'cherry', 'date'], dtype=object)

# %%
#The count of each unique value in the Series
s.value_counts()
# Out:
# fruits
# apple     1
# banana    1
# cherry    1
# date      1
# Name: count, dtype: int64

# %% [markdown]
# Task 4.2: Exploring a DataFrame

# %%
# student_data
# The first 2 rows of the DataFrame.
dfs.head(2)
# Out:
#     name  age        major
# 0  Alice   20           CS
# 1    Bob   21  Engineering

# %%
# The last row of the DataFrame.
dfs.tail(2)
# Out:
#       name  age        major
# 1      Bob   21  Engineering
# 2  Charlie   19         Math

# %%
# The index of the DataFrame
dfs.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# The column names of the DataFrame
dfs.columns
# Out:
# Index(['name', 'age', 'major'], dtype='object')

# %%
#  A concise summary of the DataFrame (including data types and non-null values).
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   major   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %% [markdown]
# Task 4.3: Selecting Columns and Rows

# %%
# employee_data
# Select and print only the 'name' column
dfe['name']
# Out:
# 0    David
# 1      Eve
# 2    Frank
# Name: name, dtype: object

# %%
#  Select and print the row at index 1.
dfe.iloc[1]
# Out:
# name                Eve
# salary            60000
# department    Marketing
# Name: 1, dtype: object

# %%
# Select and print the 'name' and 'salary' columns.
dfe[['name','salary']]
# Out:
#     name  salary
# 0  David   50000
# 1    Eve   60000
# 2  Frank   55000

# %%
# Select and print the first two rows and the 'name' and 'department' columns
dfe[['name','department']].iloc[0:2]
# Out:
#     name department
# 0  David      Sales
# 1    Eve  Marketing

# %% [markdown]
# 5. Operations on DataFrames

# %% [markdown]
# Task 5.1: Adding a New Column

# %%
dfs["City"]= ['New York', 'London', 'Paris']
dfs
# Out:
#       name  age        major      City
# 0    Alice   20           CS  New York
# 1      Bob   21  Engineering    London
# 2  Charlie   19         Math     Paris

# %% [markdown]
# Task 5.2: Removing a Column

# %%
dfs.drop(['City'],axis=1)
# Out:
#       name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math

# %% [markdown]
# Task 5.3: Filtering Rows Based on a Condition

# %%
# Using the employee_data DataFrame, filter and print the rows where the 'department' is 'Sales'.
dfe[dfe['department']=='Sales']
# Out:
#     name  salary department
# 0  David   50000      Sales
# 2  Frank   55000      Sales

# %% [markdown]
# Task 5.4: Sorting a DataFrame

# %%
# Sort the employee_data DataFrame by the 'salary' column in descending order

d = dfe['salary'].sort_values(ascending=False)
d
# Out:
# 1    60000
# 2    55000
# 0    50000
# Name: salary, dtype: int64

# %% [markdown]
# Task 5.5: Basic Aggregation

# %%
# Using the employee_data DataFrame, calculate and print the average salary of all employees.
Average_Salary = dfe['salary'].sum() / 3
Average_Salary
# Out:
# np.float64(55000.0)
